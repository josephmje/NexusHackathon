# %% [markdown]
# # Ingesing OpenNeuro datasets into  Blue Brain Nexus
# ---
# Date: Nov 22, 2019
# Hack Group Members:
# - Jay Hennessy
# - Adeel Ansari
# - John Griffiths
# - Michael Joseph
#
# The goal of this group is to crawl OpenNeuro datasets with datalad and ingest project resources into nexus.
#
#
# The python environment must include pynidm, datalad, pybids and nexus-sdk.
# (Note: the script we used from pynidm (BIDSMRI2NIRM.py) had to be tweaked since it threw errors if subject level jsons were not described for each datatype. It was also not compatible with most recent version of pybids.)
#
# The steps are:
#  - crawl openneuro with datalad
#  - produce nidm *.json* output files for each project
#  - tweak the nidm *.json* files to be compatible with nexus
#  - import the nidm resources into nexus
#
# Before we began we created a local folder for storing project datasets and one for NIDM outputs:
#  /path/to/projects
#  /path/to/rdf_files

# %% [markdown]
# ## Step 1: Get the OpenFMRI data with Datalad

# %%
# Set up environment 
import os
import glob
import json
from pprint import pprint
from subprocess import Popen, PIPE
import nexussdk as nexus
from datalad.coreapi import metadata, extract_metadata, install
from nidm.experiment.tools.BIDSMRI2NIDM import main as bids2nidm

# Folder Configs:
proj_folder = '/external/nexus_temp/nexus_temp2/projects'
rdf_folder = '/external/nexus_temp/nexus_temp2/rdf_files'
nexus_res_folder = '/external/nexus_temp/nexus_temp2/nexus_resources'
source = '///openfmri'

# Nexus Configs:
nexus_deployment = "https://nexus-research.camh.ca/v1" # Change this to your instance of nexus
token = '' # get the token from your instance of nexus. (follow the tutorial at https://bluebrainnexus.io/docs/tutorial/index.html)
org = "users"
project = "jays_test"

# get the data  using datalad
os.chdir(proj_folder)
openfmri = install(source, recursive=True)

# %%
# Get a list of project folders
datasets = list(filter(os.path.isdir, glob.glob(proj_folder+'/openfmri/*')))
try:
    datasets.remove(proj_folder+'/openfmri/scripts') # datalad includes a scripts folder, so remove it
except:
    print('no scripts file, FYI')
    
#pprint(datasets)

# %% [markdown]
# ## Step 2: Create NIDM Outputs

# %%
# run pynidm's BIDSMRI2NIDM on each dataset
# Need to use subprocess since bids2nidm is a command line script
# Also, not all the script on OpenNeuro adhere to bids properly so these projects will fail and be skipped
for d in datasets:
    output = os.path.join(rdf_folder, os.path.basename(d)+'.json')
    
    argv = ['/opt/pyNIDM/PyNIDM/nidm/experiment/tools/BIDSMRI2NIDM.py',
        '-d', d,
        '-o', output,
        '--jsonld',
        '--bidsignore'
        ]
    try:
        out = Popen(argv, stdout=PIPE, stderr=PIPE)
        stdout, stderr = out.communicate()
        if out.returncode is not 0:
            print('{} messed up. return code {}, stderr: {}'.format(d, out.returncode, stderr))
        else:
            print('{} Success, returncode: {}, output: {}'.format(os.path.basename(d), out.returncode, output))
    except Exception as e:
        print('{} Exception happened calling bids2nidm: {}'.format(d, e))
# Out:
# ds000001 Success, returncode: 0, output: /external/nexus_temp/nexus_temp2/rdf_files/ds000001.json
# ds000002 Success, returncode: 0, output: /external/nexus_temp/nexus_temp2/rdf_files/ds000002.json
# ds000003 Success, returncode: 0, output: /external/nexus_temp/nexus_temp2/rdf_files/ds000003.json
# ds000005 Success, returncode: 0, output: /external/nexus_temp/nexus_temp2/rdf_files/ds000005.json
# ds000006 Success, returncode: 0, output: /external/nexus_temp/nexus_temp2/rdf_files/ds000006.json
# /external/nexus_temp/nexus_temp2/projects/openfmri/ds000007 messed up. return code 1, stderr: b'Traceback (most recent call last):\n  File "/opt/pyNIDM/PyNIDM/nidm/experiment/tools/BIDSMRI2NIDM.py", line 612, in <module>\n    main(sys.argv[1:])\n  File "/opt/pyNIDM/PyNIDM/nidm/experiment/tools/BIDSMRI2NIDM.py", line 134, in main\n    project = bidsmri2project(directory,args)\n  File "/opt/pyNIDM/PyNIDM/nidm/experiment/tools/BIDSMRI2NIDM.py", line 234, in bidsmri2project\n    bids_layout = BIDSLayout(directory)\n  File "/opt/anaconda3/envs/prunner37/lib/python3.7/site-packages/bids/layout/layout.py", line 252, in __init__\n    indexer.index_metadata()\n  File "/opt/anaconda3/envs/prunner37/lib/python3.7/site-packages/bids/layout/index.py", line 212, in index_metadata\n    with open(bf.path, \'r\') as handle:\nFileNotFoundError: [Errno 2] No such file or directory: \'/external/nexus_temp/nexus_temp2/projects/openfmri/ds000007/sub-01/anat/sub-01_inplaneT2.json\'\n'
# ds000008 Success, returncode: 0, output: /external/nexus_temp/nexus_temp2/rdf_files/ds000008.json
# /external/nexus_temp/nexus_temp2/projects/openfmri/ds000009 messed up. return code 1, stderr: b'Traceback (most recent call last):\n  File "/opt/pyNIDM/PyNIDM/nidm/experiment/tools/BIDSMRI2NIDM.py", line 612, in <module>\n    main(sys.argv[1:])\n  File "/opt/pyNIDM/PyNIDM/nidm/experiment/tools/BIDSMRI2NIDM.py", line 134, in main\n    project = bidsmri2project(directory,args)\n  File "/opt/pyNIDM/PyNIDM/nidm/experiment/tools/BIDSMRI2NIDM.py", line 234, in bidsmri2project\n    bids_layout = BIDSLayout(directory)\n  File "/opt/anaconda3/envs/prunner37/lib/python3.7/site-packages/bids/layout/layout.py", line 252, in __init__\n    indexer.index_metadata()\n  File "/opt/anaconda3/envs/prunner37/lib/python3.7/site-packages/bids/layout/index.py", line 212, in index_metadata\n    with open(bf.path, \'r\') as handle:\nFileNotFoundError: [Errno 2] No such file or directory: \'/external/nexus_temp/nexus_temp2/projects/openfmri/ds000009/sub-01/anat/sub-01_inplaneT2.json\'\n'
# ds000011 Success, returncode: 0, output: /external/nexus_temp/nexus_temp2/rdf_files/ds000011.json
# ds000017 Success, returncode: 0, output: /external/nexus_temp/nexus_temp2/rdf_files/ds000017.json
# /external/nexus_temp/nexus_temp2/projects/openfmri/ds000017A messed up. return code 1, stderr: b'CRITICAL:root:Cannot find dataset_description.json file which is required in the BIDS spec\n-1\n'
# /external/nexus_temp/nexus_temp2/projects/openfmri/ds000017B messed up. return code 1, stderr: b'CRITICAL:root:Cannot find dataset_description.json file which is required in the BIDS spec\n-1\n'
# /external/nexus_temp/nexus_temp2/projects/openfmri/ds000030 messed up. return code 1, stderr: b'Traceback (most recent call last):\n  File "/opt/pyNIDM/PyNIDM/nidm/experiment/tools/BIDSMRI2NIDM.py", line 612, in <module>\n    main(sys.argv[1:])\n  File "/opt/pyNIDM/PyNIDM/nidm/experiment/tools/BIDSMRI2NIDM.py", line 134, in main\n    project = bidsmri2project(directory,args)\n  File "/opt/pyNIDM/PyNIDM/nidm/experiment/tools/BIDSMRI2NIDM.py", line 234, in bidsmri2project\n    bids_layout = BIDSLayout(directory)\n  File "/opt/anaconda3/envs/prunner37/lib/python3.7/site-packages/bids/layout/layout.py", line 252, in __init__\n    indexer.index_metadata()\n  File "/opt/anaconda3/envs/prunner37/lib/python3.7/site-packages/bids/layout/index.py", line 212, in index_metadata\n    with open(bf.path, \'r\') as handle:\nFileNotFoundError: [Errno 2] No such file or directory: \'/external/nexus_temp/nexus_temp2/projects/openfmri/ds000030/phenotype/acds_adult.json\'\n'
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-6b71fd623e77> in <module>
#      12     try:
#      13         out = Popen(argv, stdout=PIPE, stderr=PIPE)
# ---> 14         stdout, stderr = out.communicate()
#      15         if out.returncode is not 0:
#      16             print('{} messed up. return code {}, stderr: {}'.format(d, out.returncode, stderr))
#
# /opt/anaconda3/envs/prunner37/lib/python3.7/subprocess.py in communicate(self, input, timeout)
#     937
#     938             try:
# --> 939                 stdout, stderr = self._communicate(input, endtime, timeout)
#     940             except KeyboardInterrupt:
#     941                 # https://bugs.python.org/issue25942
#
# /opt/anaconda3/envs/prunner37/lib/python3.7/subprocess.py in _communicate(self, input, endtime, orig_timeout)
#    1679                         raise TimeoutExpired(self.args, orig_timeout)
#    1680
# -> 1681                     ready = selector.select(timeout)
#    1682                     self._check_timeout(endtime, orig_timeout)
#    1683
#
# /opt/anaconda3/envs/prunner37/lib/python3.7/selectors.py in select(self, timeout)
#     413         ready = []
#     414         try:
# --> 415             fd_event_list = self._selector.poll(timeout)
#     416         except InterruptedError:
#     417             return ready
#
# KeyboardInterrupt:

# %% [markdown]
# ## Step 3: Update NIDM RDF Outputs

# %%
def update_resource(nidm_file, nexus_file):
    """ Changes the json nidm output to be compatible
        with nexus.
        Return 0 is success or 1 if failed.
    """
    try:
        with open(nidm_file, 'r') as f:
            data = json.load(f)

        del data["@context"]["records"]
        del data['@context']['@version']
        
        context = data["@context"]
        shapes = data["@graph"]

        context_list = ["https://bluebrain.github.io/nexus/contexts/shacl-20170720.json",
                        "https://bluebrain.github.io/nexus/contexts/resource.json"]

        context_list.append(context)

        data["@context"] = context_list
        data["shapes"] = shapes
        data["@type"] = "owl:Ontology"
        del data["@graph"]
        
        
        
        with open(nexus_file, 'w') as f:
            json.dump(data, f)
        return 0
    except Exception as e:
        print('Failed updating resource {}, {}'.format(nidm_file, e))
        return 1

# %%
# Need to tweak the nidm json-ld output to be compatible with nexus
nidm_outputs = list(filter(os.path.isfile, glob.glob(rdf_folder+'/*')))
nexus_outputs = list(map(lambda x: x.replace('rdf_files', 'nexus_resources'), nidm_outputs))

nexus_success = map(update_resource, nidm_outputs, nexus_outputs)

#Check if all the json-ld's updated successfully
if not sum(nexus_success):
    print('Update Success!')
# Out:
# ['/external/nexus_temp/nexus_temp2/rdf_files/ds000001.json',
#  '/external/nexus_temp/nexus_temp2/rdf_files/ds000002.json',
#  '/external/nexus_temp/nexus_temp2/rdf_files/ds000003.json',
#  '/external/nexus_temp/nexus_temp2/rdf_files/ds000005.json',
#  '/external/nexus_temp/nexus_temp2/rdf_files/ds000006.json',
#  '/external/nexus_temp/nexus_temp2/rdf_files/ds000008.json',
#  '/external/nexus_temp/nexus_temp2/rdf_files/ds000011.json',
#  '/external/nexus_temp/nexus_temp2/rdf_files/ds000017.json']
# ['/external/nexus_temp/nexus_temp2/nexus_resources/ds000001.json',
#  '/external/nexus_temp/nexus_temp2/nexus_resources/ds000002.json',
#  '/external/nexus_temp/nexus_temp2/nexus_resources/ds000003.json',
#  '/external/nexus_temp/nexus_temp2/nexus_resources/ds000005.json',
#  '/external/nexus_temp/nexus_temp2/nexus_resources/ds000006.json',
#  '/external/nexus_temp/nexus_temp2/nexus_resources/ds000008.json',
#  '/external/nexus_temp/nexus_temp2/nexus_resources/ds000011.json',
#  '/external/nexus_temp/nexus_temp2/nexus_resources/ds000017.json']
# Update Success!

# %% [markdown]
# ## Step 4: Upload Nexus Resources

# %%
# Initialize Nexus than loop through the nexus json-lds and upload each resource.
nexus.config.set_environment(nexus_deployment)
nexus.config.set_token(token)
nexus.permissions.fetch()

for nexus_file in nexus_outputs:
    with open(nexus_file, 'r') as f:
        data = json.load(f)
    payload = nexus.resources.create(org, project,data)
# Out:
# <class 'dict'>
# OrderedDict([('@context',
#               'https://bluebrain.github.io/nexus/contexts/resource.json'),
#              ('@id',
#               'https://nexus-research.camh.ca/v1/resources/users/jays_test/_/7d539f01-ecae-499f-bcdb-f005a524b42a'),
#              ('@type', 'http://www.w3.org/2002/07/owl#Ontology'),
#              ('_self',
#               'https://nexus-research.camh.ca/v1/resources/users/jays_test/_/7d539f01-ecae-499f-bcdb-f005a524b42a'),
#              ('_constrainedBy',
#               'https://bluebrain.github.io/nexus/schemas/unconstrained.json'),
#              ('_project',
#               'https://nexus-research.camh.ca/v1/projects/users/jays_test'),
#              ('_rev', 1),
#              ('_deprecated', False),
#              ('_createdAt', '2019-12-16T19:15:43.876937Z'),
#              ('_createdBy',
#               'https://nexus-research.camh.ca/v1/realms/camh/users/jay_hennessy'),
#              ('_updatedAt', '2019-12-16T19:15:43.876937Z'),
#              ('_updatedBy',
#               'https://nexus-research.camh.ca/v1/realms/camh/users/jay_hennessy'),
#              ('_incoming',
#               'https://nexus-research.camh.ca/v1/resources/users/jays_test/_/7d539f01-ecae-499f-bcdb-f005a524b42a/incoming'),
#              ('_outgoing',
#               'https://nexus-research.camh.ca/v1/resources/users/jays_test/_/7d539f01-ecae-499f-bcdb-f005a524b42a/outgoing')])
# <class 'dict'>
# OrderedDict([('@context',
#               'https://bluebrain.github.io/nexus/contexts/resource.json'),
#              ('@id',
#               'https://nexus-research.camh.ca/v1/resources/users/jays_test/_/ae69e5cf-d98b-4914-b1a1-1ec7b14f2356'),
#              ('@type', 'http://www.w3.org/2002/07/owl#Ontology'),
#              ('_self',
#               'https://nexus-research.camh.ca/v1/resources/users/jays_test/_/ae69e5cf-d98b-4914-b1a1-1ec7b14f2356'),
#              ('_constrainedBy',
#               'https://bluebrain.github.io/nexus/schemas/unconstrained.json'),
#              ('_project',
#               'https://nexus-research.camh.ca/v1/projects/users/jays_test'),
#              ('_rev', 1),
#              ('_deprecated', False),
#              ('_createdAt', '2019-12-16T19:15:44.402824Z'),
#              ('_createdBy',
#               'https://nexus-research.camh.ca/v1/realms/camh/users/jay_hennessy'),
#              ('_updatedAt', '2019-12-16T19:15:44.402824Z'),
#              ('_updatedBy',
#               'https://nexus-research.camh.ca/v1/realms/camh/users/jay_hennessy'),
#              ('_incoming',
#               'https://nexus-research.camh.ca/v1/resources/users/jays_test/_/ae69e5cf-d98b-4914-b1a1-1ec7b14f2356/incoming'),
#              ('_outgoing',
#               'https://nexus-research.camh.ca/v1/resources/users/jays_test/_/ae69e5cf-d98b-4914-b1a1-1ec7b14f2356/outgoing')])
# <class 'dict'>
# OrderedDict([('@context',
#               'https://bluebrain.github.io/nexus/contexts/resource.json'),
#              ('@id',
#               'https://nexus-research.camh.ca/v1/resources/users/jays_test/_/99467af5-66c4-4471-9976-83219f19bdd7'),
#              ('@type', 'http://www.w3.org/2002/07/owl#Ontology'),
#              ('_self',
#               'https://nexus-research.camh.ca/v1/resources/users/jays_test/_/99467af5-66c4-4471-9976-83219f19bdd7'),
#              ('_constrainedBy',
#               'https://bluebrain.github.io/nexus/schemas/unconstrained.json'),
#              ('_project',
#               'https://nexus-research.camh.ca/v1/projects/users/jays_test'),
#              ('_rev', 1),
#              ('_deprecated', False),
#              ('_createdAt', '2019-12-16T19:15:44.672658Z'),
#              ('_createdBy',
#               'https://nexus-research.camh.ca/v1/realms/camh/users/jay_hennessy'),
#              ('_updatedAt', '2019-12-16T19:15:44.672658Z'),
#              ('_updatedBy',
#               'https://nexus-research.camh.ca/v1/realms/camh/users/jay_hennessy'),
#              ('_incoming',
#               'https://nexus-research.camh.ca/v1/resources/users/jays_test/_/99467af5-66c4-4471-9976-83219f19bdd7/incoming'),
#              ('_outgoing',
#               'https://nexus-research.camh.ca/v1/resources/users/jays_test/_/99467af5-66c4-4471-9976-83219f19bdd7/outgoing')])
# <class 'dict'>
# OrderedDict([('@context',
#               'https://bluebrain.github.io/nexus/contexts/resource.json'),
#              ('@id',
#               'https://nexus-research.camh.ca/v1/resources/users/jays_test/_/13654b7c-1e95-4cc7-8e2d-d2ceee0a9c02'),
#              ('@type', 'http://www.w3.org/2002/07/owl#Ontology'),
#              ('_self',
#               'https://nexus-research.camh.ca/v1/resources/users/jays_test/_/13654b7c-1e95-4cc7-8e2d-d2ceee0a9c02'),
#              ('_constrainedBy',
#               'https://bluebrain.github.io/nexus/schemas/unconstrained.json'),
#              ('_project',
#               'https://nexus-research.camh.ca/v1/projects/users/jays_test'),
#              ('_rev', 1),
#              ('_deprecated', False),
#              ('_createdAt', '2019-12-16T19:15:44.928427Z'),
#              ('_createdBy',
#               'https://nexus-research.camh.ca/v1/realms/camh/users/jay_hennessy'),
#              ('_updatedAt', '2019-12-16T19:15:44.928427Z'),
#              ('_updatedBy',
#               'https://nexus-research.camh.ca/v1/realms/camh/users/jay_hennessy'),
#              ('_incoming',
#               'https://nexus-research.camh.ca/v1/resources/users/jays_test/_/13654b7c-1e95-4cc7-8e2d-d2ceee0a9c02/incoming'),
#              ('_outgoing',
#               'https://nexus-research.camh.ca/v1/resources/users/jays_test/_/13654b7c-1e95-4cc7-8e2d-d2ceee0a9c02/outgoing')])
# <class 'dict'>
# OrderedDict([('@context',
#               'https://bluebrain.github.io/nexus/contexts/resource.json'),
#              ('@id',
#               'https://nexus-research.camh.ca/v1/resources/users/jays_test/_/73ad7749-2479-4f83-9e9d-45a4bde044fb'),
#              ('@type', 'http://www.w3.org/2002/07/owl#Ontology'),
#              ('_self',
#               'https://nexus-research.camh.ca/v1/resources/users/jays_test/_/73ad7749-2479-4f83-9e9d-45a4bde044fb'),
#              ('_constrainedBy',
#               'https://bluebrain.github.io/nexus/schemas/unconstrained.json'),
#              ('_project',
#               'https://nexus-research.camh.ca/v1/projects/users/jays_test'),
#              ('_rev', 1),
#              ('_deprecated', False),
#              ('_createdAt', '2019-12-16T19:15:45.548300Z'),
#              ('_createdBy',
#               'https://nexus-research.camh.ca/v1/realms/camh/users/jay_hennessy'),
#              ('_updatedAt', '2019-12-16T19:15:45.548300Z'),
#              ('_updatedBy',
#               'https://nexus-research.camh.ca/v1/realms/camh/users/jay_hennessy'),
#              ('_incoming',
#               'https://nexus-research.camh.ca/v1/resources/users/jays_test/_/73ad7749-2479-4f83-9e9d-45a4bde044fb/incoming'),
#              ('_outgoing',
#               'https://nexus-research.camh.ca/v1/resources/users/jays_test/_/73ad7749-2479-4f83-9e9d-45a4bde044fb/outgoing')])
# <class 'dict'>
# OrderedDict([('@context',
#               'https://bluebrain.github.io/nexus/contexts/resource.json'),
#              ('@id',
#               'https://nexus-research.camh.ca/v1/resources/users/jays_test/_/380c3c52-6e3d-4bdd-91e2-521464e71284'),
#              ('@type', 'http://www.w3.org/2002/07/owl#Ontology'),
#              ('_self',
#               'https://nexus-research.camh.ca/v1/resources/users/jays_test/_/380c3c52-6e3d-4bdd-91e2-521464e71284'),
#              ('_constrainedBy',
#               'https://bluebrain.github.io/nexus/schemas/unconstrained.json'),
#              ('_project',
#               'https://nexus-research.camh.ca/v1/projects/users/jays_test'),
#              ('_rev', 1),
#              ('_deprecated', False),
#              ('_createdAt', '2019-12-16T19:15:45.870518Z'),
#              ('_createdBy',
#               'https://nexus-research.camh.ca/v1/realms/camh/users/jay_hennessy'),
#              ('_updatedAt', '2019-12-16T19:15:45.870518Z'),
#              ('_updatedBy',
#               'https://nexus-research.camh.ca/v1/realms/camh/users/jay_hennessy'),
#              ('_incoming',
#               'https://nexus-research.camh.ca/v1/resources/users/jays_test/_/380c3c52-6e3d-4bdd-91e2-521464e71284/incoming'),
#              ('_outgoing',
#               'https://nexus-research.camh.ca/v1/resources/users/jays_test/_/380c3c52-6e3d-4bdd-91e2-521464e71284/outgoing')])
# <class 'dict'>
# OrderedDict([('@context',
#               'https://bluebrain.github.io/nexus/contexts/resource.json'),
#              ('@id',
#               'https://nexus-research.camh.ca/v1/resources/users/jays_test/_/57a7fb6a-a649-4a84-b611-f2b67d779304'),
#              ('@type', 'http://www.w3.org/2002/07/owl#Ontology'),
#              ('_self',
#               'https://nexus-research.camh.ca/v1/resources/users/jays_test/_/57a7fb6a-a649-4a84-b611-f2b67d779304'),
#              ('_constrainedBy',
#               'https://bluebrain.github.io/nexus/schemas/unconstrained.json'),
#              ('_project',
#               'https://nexus-research.camh.ca/v1/projects/users/jays_test'),
#              ('_rev', 1),
#              ('_deprecated', False),
#              ('_createdAt', '2019-12-16T19:15:46.180524Z'),
#              ('_createdBy',
#               'https://nexus-research.camh.ca/v1/realms/camh/users/jay_hennessy'),
#              ('_updatedAt', '2019-12-16T19:15:46.180524Z'),
#              ('_updatedBy',
#               'https://nexus-research.camh.ca/v1/realms/camh/users/jay_hennessy'),
#              ('_incoming',
#               'https://nexus-research.camh.ca/v1/resources/users/jays_test/_/57a7fb6a-a649-4a84-b611-f2b67d779304/incoming'),
#              ('_outgoing',
#               'https://nexus-research.camh.ca/v1/resources/users/jays_test/_/57a7fb6a-a649-4a84-b611-f2b67d779304/outgoing')])
# <class 'dict'>
# OrderedDict([('@context',
#               'https://bluebrain.github.io/nexus/contexts/resource.json'),
#              ('@id',
#               'https://nexus-research.camh.ca/v1/resources/users/jays_test/_/b4ad38dd-81db-4fc6-891a-e87ba2ae0b35'),
#              ('@type', 'http://www.w3.org/2002/07/owl#Ontology'),
#              ('_self',
#               'https://nexus-research.camh.ca/v1/resources/users/jays_test/_/b4ad38dd-81db-4fc6-891a-e87ba2ae0b35'),
#              ('_constrainedBy',
#               'https://bluebrain.github.io/nexus/schemas/unconstrained.json'),
#              ('_project',
#               'https://nexus-research.camh.ca/v1/projects/users/jays_test'),
#              ('_rev', 1),
#              ('_deprecated', False),
#              ('_createdAt', '2019-12-16T19:15:46.525733Z'),
#              ('_createdBy',
#               'https://nexus-research.camh.ca/v1/realms/camh/users/jay_hennessy'),
#              ('_updatedAt', '2019-12-16T19:15:46.525733Z'),
#              ('_updatedBy',
#               'https://nexus-research.camh.ca/v1/realms/camh/users/jay_hennessy'),
#              ('_incoming',
#               'https://nexus-research.camh.ca/v1/resources/users/jays_test/_/b4ad38dd-81db-4fc6-891a-e87ba2ae0b35/incoming'),
#              ('_outgoing',
#               'https://nexus-research.camh.ca/v1/resources/users/jays_test/_/b4ad38dd-81db-4fc6-891a-e87ba2ae0b35/outgoing')])

# %% [markdown]
# ### All done!
#
# If you have any questions you can reach me at jay.hennessy@camh.ca.
